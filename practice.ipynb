# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# ОСНОВНЫЕ НАСТРОЙКИ
DATASET_PATH = "dataset" # путь к папке с изображениями
IMG_SIZE = (224, 224) # размер картинок для модели
BATCH_SIZE = 32
EPOCHS = 10

# ГЕНЕРАТОРЫ ДАННЫХ
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_gen = datagen.flow_from_directory(
    DATASET_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="binary",
    subset="training"
)

val_gen = datagen.flow_from_directory(
    DATASET_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="binary",
    subset="validation"
)

# МОДЕЛЬ (ПРЕДОБУЧЕННАЯ)
base_model = MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights="imagenet"
)

for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation="relu")(x)
output = Dense(1, activation="sigmoid")(x)

model = Model(inputs=base_model.input, outputs=output)

model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model.summary()

# ОБУЧЕНИЕ
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS
)

# СОХРАНЕНИЕ МОДЕЛИ
model.save("wildfire_model.h5")
print("Модель сохранена!")


# ГРАФИКИ ОБУЧЕНИЯ
plt.plot(history.history["accuracy"], label="train acc")
plt.plot(history.history["val_accuracy"], label="val acc")
plt.legend()
plt.title("Training Accuracy")
plt.show()
# Out:
# Found 800 images belonging to 2 classes.
# Found 199 images belonging to 2 classes.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv1 (Conv2D)                │ (None, 112, 112, 32)      │             864 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bn_Conv1 (BatchNormalization) │ (None, 112, 112, 32)      │             128 │ Conv1[0][0]                │
# ...

# %%
IMG_SIZE = (224, 224)  # размер, который использовался при обучении

def prepare_image(image_path):
    img = load_img(image_path, target_size=IMG_SIZE)  # загрузка и ресайз
    img_array = img_to_array(img) / 255.0             # нормализация
    img_array = np.expand_dims(img_array, axis=0)    # добавить batch dimension
    return img_array

# %%
# ФУНКЦИЯ ПРЕДСКАЗАНИЯ
def predict_wildfire(image_path):
    img_array = prepare_image(image_path)
    prediction = model.predict(img_array)[0][0]

    if prediction > 0.5:
        print(f"Обнаружен пожар! Вероятность: {prediction*100:.0f}%")
    else:
        print(f"Пожара нет. Вероятность: {prediction*100:.0f}%")

# %%
# ТЕСТ
predict_wildfire("test_images/test_image1.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Обнаружен пожар! Вероятность: 96%
